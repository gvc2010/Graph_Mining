# %% [markdown]
# <a href="https://colab.research.google.com/github/gvc2010/Graph_Mining/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Carregar a matriz de adjacências do arquivo CSV
matriz_adj1 = pd.read_csv('Grafo3.csv', delimiter=',', header=None)

# Criar o grafo G a partir da matriz de adjacências
G3 = nx.from_pandas_adjacency(matriz_adj1)

# Verificar se o grafo é direcionado
direcionado = nx.is_directed(G3)
print('O grafo G3 é direcionado:', direcionado)

# Desenhar o grafo G na tela com dimensões 12 x 7
plt.figure(figsize=(12, 7))
nx.draw(G3, with_labels=True, node_size=300, node_color='skyblue', font_size=10, font_color='black', arrowsize=10)
plt.title('Grafo G3')
plt.show()

# Extração da quantidade de vértices e de arestas do grafo G
quantidade_vertices = G3.order()
quantidade_arestas = G3.size()
print('Quantidade de vértices do grafo G3:', quantidade_vertices)
print('Quantidade de arestas do grafo G3:', quantidade_arestas)

# Extração do grau do vértice 33 e diferença em relação ao grau médio da rede
grau_vertice_33 = G3.degree(33)
graus_G3 = dict(G3.degree())
grau_medio_G3 = np.mean(list(graus_G3.values()))
diferenca_grau = grau_vertice_33 - grau_medio_G3
print('Grau do vértice 33 do grafo G3:', grau_vertice_33)
print('Diferença do grau do vértice 33 em relação ao grau médio da rede:', diferenca_grau)

# Extração do conjunto de arestas que se conectam ao vértice 33
arestas_vertice_33 = list(G3.edges(33))
print('Conjunto de arestas que se conectam ao vértice 33:', arestas_vertice_33)

# Apresentar a distribuição de graus do grafo G em uma figura com dimensões 10 x 5
plt.figure(figsize=(10, 5))
plt.hist(list(graus_G3.values()), bins=20, color='skyblue', edgecolor='black')
plt.title('Distribuição de graus do Grafo G3')
plt.xlabel('Grau')
plt.ylabel('Quantidade')
plt.grid(True)
plt.show()
# Out:
# O grafo G3 é direcionado: False
# Quantidade de vértices do grafo G3: 512
# Quantidade de arestas do grafo G3: 512
# Grau do vértice 33 do grafo G3: 3
# Diferença do grau do vértice 33 em relação ao grau médio da rede: 1.0
# Conjunto de arestas que se conectam ao vértice 33: [(33, 32), (33, 34), (33, 335)]
